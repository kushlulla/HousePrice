# %% [markdown]
# # Surprise Housing Assignment

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np # Math Functions
import pandas as pd #Data managment and processing 
import matplotlib.pyplot as plt #Data visualization
import seaborn as sns #Data visualization 
import plotly.express as px # Advanced Data visualization 
import warnings # Avoid warings that might arrise from data visualization
warnings.filterwarnings('ignore')
import datetime # For time line analisys
import random

# %% [markdown]
# ### Importing the data from the csv file provided

# %%
housing_df= pd.read_csv("Data/train.csv")
housing_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Adding code to see all the columns of data set
pd.set_option('display.max_columns', 81)
housing_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ### EDA and Cleaning the data

# %%
# lets check the columsn and if we have any missing values
housing_df.info(verbose = True, show_counts=True,)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# From the data distionary we know that NA stands for not available and not missing value.
# so we do not need to alter the data for columns that are object Type

# %% [markdown]
# Since we have the value for only 0.5% data for PoolQC we can drop it

# %%
housing_df.drop(["PoolQC","PoolArea"],axis=1,inplace=True)

# %%
housing_df["MiscFeature"].value_counts()
# Out:
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: MiscFeature, dtype: int64

# %%
# since we have only a few values in MiscFeature we can change them into a shed yes/no and drop the other data 
housing_df['Shed']=np.where(housing_df['MiscFeature']=='Shed',1,0)
housing_df.drop("MiscFeature",axis=1,inplace=True)

# %%
housing_df['Fireplaces'].value_counts()
# Out:
# 0    690
# 1    650
# 2    115
# 3      5
# Name: Fireplaces, dtype: int64

# %%
#Filling Null values
null_fill=["GarageType","Alley","Fence","FireplaceQu","BsmtFinType1","BsmtFinType2","BsmtQual","BsmtCond","BsmtExposure","GarageFinish","GarageQual","GarageCond","MasVnrType"]
for x in null_fill:
    housing_df[x].fillna("No",inplace=True)

# %%
#Filling Electrical null values with the most common electrical system
housing_df.Electrical.fillna(housing_df.Electrical.value_counts().index[0],inplace=True)

# %%
# Lets see if we have any more null values left 
housing_df.columns[housing_df.isna().any()].tolist()
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
# we can fill LotFrontage with median as it is a numeric value
housing_df.LotFrontage.fillna(housing_df.LotFrontage.median(),inplace=True)

# %%
housing_df[housing_df.MasVnrArea.isna()].MasVnrType
# Out:
# 234     No
# 529     No
# 650     No
# 936     No
# 973     No
# 977     No
# 1243    No
# 1278    No
# Name: MasVnrType, dtype: object

# %%
# We can see that null values in MasVnrArea are all for Masonry veneer type None so we can fill it with 0
housing_df.MasVnrArea.fillna(0,inplace=True)

# %%
housing_df[housing_df.GarageYrBlt.isna()].GarageType.value_counts()
# Out:
# No    81
# Name: GarageType, dtype: int64

# %%
# all null values are for the houses with no garage so we can fill it with 0
housing_df.GarageYrBlt.fillna(0,inplace=True)

# %% [markdown]
# Now the data has no null Values present in the dataframe Lets explore the data and see what we can observe

# %%
def count_show(col):
    pal=["tab10","hls","husl","Set2","Paired","flare"]
    sns.countplot(col,palette=random.choice(pal))
    plt.show()

# %%
def hist_show(col,y=7):
    pal=["tab10","hls","husl","Set2","Paired","flare"]
    sns.histplot(col,palette=random.choice(pal),bins=y,kde=True)
    plt.show()

# %%
hist_show(housing_df.SalePrice,12)

# %% [markdown]
# Most of the properties sold between 10,000- 15,000

# %%
hist_show(housing_df.LotArea,20)

# %% [markdown]
# we seem to have a huge outlier in the area that neeeds to be seen more carefully

# %%
count_show(housing_df.MSZoning)

# %% [markdown]
# Majority of the properties are Residential Low Density

# %%
count_show(housing_df.BldgType)

# %% [markdown]
# Most of the houses are Single-family Detached

# %%
count_show(housing_df.HouseStyle)

# %% [markdown]
# Most of the houses are One story

# %%
count_show(housing_df.OverallQual)

# %% [markdown]
# Most of the houses are Average or Above Average, lower quality homes are very few

# %%
count_show(housing_df.OverallCond)

# %% [markdown]
# The over all condition of most houses are Average

# %%
hist_show(housing_df.YearBuilt,12)

# %% [markdown]
# The year of built ranges from 1880 to 2010 with 2000-2010 having the most build, also we see a slight dip in the years 1970-1990

# %%
# build a new column for building age
housing_df['Age']=2022-housing_df.YearBuilt
housing_df.Age.describe()
# Out:
# count    1460.000000
# mean       50.732192
# std        30.202904
# min        12.000000
# 25%        22.000000
# 50%        49.000000
# 75%        68.000000
# max       150.000000
# Name: Age, dtype: float64

# %% [markdown]
# The oldest property is 150 Years old and the newest property is 12 years old with the avarage age being 50

# %%
plt.figure(figsize=(8,8))
sns.boxplot(data=housing_df.Age)
plt.show()

# %% [markdown]
# We can see that there are a few outliers that are very old

# %%
#lets see how many houses have been remodeled after being built 
housing_df['Remod']=housing_df.YearRemodAdd-housing_df.YearBuilt
len(housing_df[housing_df.Remod==0])
# Out:
# 764

# %% [markdown]
# 50% of the houses were Remodeled at some point.
# We can drop the build year since the data is saved in the the form of age

# %%
housing_df.drop("YearBuilt",axis=1,inplace=True)

# %% [markdown]
# ### Bivariant analisys with the target variable
# To do this lets write a custom function to do the same.

# %%
def price_vs(df,col,sc=True):
    if sc:
        sns.scatterplot(data=df,y="SalePrice",x=col)
    else:
        sns.catplot(data=df,x=col,y="SalePrice")
        plt.xticks(rotation=45)
    plt.show()

# %%
price_vs(housing_df,"Age")

# %% [markdown]
# Age alone is not a strong predictor of price

# %%
price_vs(housing_df,"OverallCond",False)

# %% [markdown]
# Overall Condition is a good predictor for the price as the minimum price of a house in good condition is better than the house with poorer condition

# %%
price_vs(housing_df,"LotArea")

# %%
# Lets drop the outliers of area and see if we get a better pattern 
price_vs(housing_df[housing_df.LotArea<10000],"LotArea")

# %% [markdown]
# Lot area alone is not a good preditor of price

# %%
price_vs(housing_df,"Neighborhood",False)

# %% [markdown]
# Some Neighborhoods have a higher sale price

# %%
price_vs(housing_df,"Condition1",False)

# %% [markdown]
# Normal is the most common and the price does not show any clear relation

# %%
price_vs(housing_df,"Fireplaces")

# %%
# Lets see if we can find co-related columns
plt.figure(figsize=(30, 30))
sns.heatmap(housing_df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Above grade (ground) living area has a high corr with sale price lets have a look at it

# %%
price_vs(housing_df,"GrLivArea")

# %%
corr_val = housing_df[list(housing_df.dtypes[housing_df.dtypes != 'object'].index)].corr()

# %%
# Lets look at highest co-relation columns  
corr_coef = corr_val[corr_val['SalePrice'] > 0.5]['SalePrice'].sort_values(ascending=False)
print(corr_coef[1:])
corr_coef_cols = [idx for idx in corr_coef.index]
# Out:
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearRemodAdd    0.507101
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(20, 20))
r=1
for va in corr_coef[1:].index:
    plt.subplot(4,3,r)
    sns.scatterplot(data=housing_df,x=va,y="SalePrice")
    r=r+1
plt.show()

# %% [markdown]
# #### Obseravtions
# * Increase in Quality gets better sale price
# * GrLiving Area is a very good predictor of the sale price
# * year of remodling isnt a very good preditor for the sale price

# %%
#Lets see if we can find ways to reduce the complexity in the catagoric variables
housing_Categories = housing_df.select_dtypes(include=['object'])
housing_Categories.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'Fence', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
plt.figure(figsize=(20, 80))
r=1
for va in housing_Categories.columns:
    plt.subplot(11,4,r)
    sns.countplot(housing_Categories[va])
    r=r+1
plt.show()

# %%
# Some columns have data that is almost 90%-95% only one value , we can drop those columns
drp=["Utilities","Street","Condition2","RoofMatl","Heating","PavedDrive"]
housing_df.drop(drp,axis=1,inplace=True)
